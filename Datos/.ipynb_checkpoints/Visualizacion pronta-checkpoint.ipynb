# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
DF_Train = pd.read_csv("train_essays.csv")
DF_Train
# Out:
#             id  prompt_id                                               text  \
# 0     0059830c          0  Cars. Cars have been around since they became ...
# 1     005db917          0  Transportation is a large necessity in most co...
# 2     008f63e3          0  "America's love affair with it's vehicles seem...
# 3     00940276          0  How often do you ride in a car? Do you drive a...
# 4     00c39458          0  Cars are a wonderful thing. They are perhaps o...
# ...        ...        ...                                                ...
# 1373  fe6ff9a5          1  There has been a fuss about the Elector Colleg...
# 1374  ff669174          0  Limiting car usage has many advantages. Such a...
# 1375  ffa247e0          0  There's a new trend that has been developing f...
# 1376  ffc237e9          0  As we all know cars are a big part of our soci...
# 1377  ffe1ca0d          0  Cars have been around since the 1800's and hav...
#
#       generated
# 0             0
# ...

# %%
prompts = pd.read_csv("train_prompts.csv")
prompts
# Out:
#    prompt_id                       prompt_name  \
# 0          0                   Car-free cities
# 1          1  Does the electoral college work?
#
#                                         instructions  \
# 0  Write an explanatory essay to inform fellow ci...
# 1  Write a letter to your state senator in which ...
#
#                                          source_text
# 0  # In German Suburb, Life Goes On Without Cars ...
# 1  # What Is the Electoral College? by the Office...

# %%
DF_Test = pd.read_csv("test_essays.csv")
DF_Test
# Out:
#          id  prompt_id          text
# 0  0000aaaa          2  Aaa bbb ccc.
# 1  1111bbbb          3  Bbb ccc ddd.
# 2  2222cccc          4  CCC ddd eee.

# %%
DF_Train.isnull().values.any()
# Out:
# False

# %%
DF_Train['generated'].value_counts()
# Out:
# generated
# 0    1375
# 1       3
# Name: count, dtype: int64

# %%
DF_Train.generated.value_counts().plot.bar()
# Out:
# <Axes: xlabel='generated'>

# %%
textos_generados = pd.read_csv("ai_generated_train_essays.csv")
textos_generados
# Out:
#            id  prompt_id                                               text  \
# 0    d429f032          0  Advantages of Limiting Car Usage \n\nLimiting ...
# 1    1ce279be          0  Advantages of Limiting Car Usage\n\nLimiting c...
# 2    c9595213          0  Limiting car usage has numerous advantages tha...
# 3    f2266d87          0  The passages provided discuss the advantages o...
# 4    eeace4bd          0  Title: The Advantages of Limiting Car Usage\n\...
# ..        ...        ...                                                ...
# 495  c67009a2          1  [Your Name]\n[Your Address]\n[City, State, ZIP...
# 496  66e830cc          1  [Your Name]\n[Your Address]\n[City, State, Zip...
# 497  5d70a380          1  [Your Name]\n[Your Address]\n[City, State, ZIP...
# 498  9a07aa27          1  [Your Name]\n[Your Address]\n[City, State, ZIP...
# 499  b79db5b8          1  [Your Name]\n[Your Address]\n[City, State, ZIP...
#
#      generated
# 0            1
# 1            1
# ...

# %%
data = pd.concat([textos_generados, DF_Train], ignore_index=True)
data
# Out:
#             id  prompt_id                                               text  \
# 0     d429f032          0  Advantages of Limiting Car Usage \n\nLimiting ...
# 1     1ce279be          0  Advantages of Limiting Car Usage\n\nLimiting c...
# 2     c9595213          0  Limiting car usage has numerous advantages tha...
# 3     f2266d87          0  The passages provided discuss the advantages o...
# 4     eeace4bd          0  Title: The Advantages of Limiting Car Usage\n\...
# ...        ...        ...                                                ...
# 1873  fe6ff9a5          1  There has been a fuss about the Elector Colleg...
# 1874  ff669174          0  Limiting car usage has many advantages. Such a...
# 1875  ffa247e0          0  There's a new trend that has been developing f...
# 1876  ffc237e9          0  As we all know cars are a big part of our soci...
# 1877  ffe1ca0d          0  Cars have been around since the 1800's and hav...
#
#       generated
# 0             1
# ...

# %%
data.generated.value_counts().plot.bar()
# Out:
# <Axes: xlabel='generated'>

# %%
New_Data = pd.read_csv("train_v2_drcat_02.csv")
New_Data
# Out:
#                                                     text  label  \
# 0      Phones\n\nModern humans today are always on th...      0
# 1      This essay will explain if drivers should or s...      0
# 2      Driving while the use of cellular devices\n\nT...      0
# 3      Phones & Driving\n\nDrivers should not be able...      0
# 4      Cell Phone Operation While Driving\n\nThe abil...      0
# ...                                                  ...    ...
# 44863  Dear Senator,\n\nI am writing to you today to ...      1
# 44864  Dear Senator,\n\nI am writing to you today to ...      1
# 44865  Dear Senator,\n\nI am writing to you today to ...      1
# 44866  Dear Senator,\n\nI am writing to you today to ...      1
# 44867  Dear Senator,\n\nI am writing to you today to ...      1
#
#                             prompt_name           source  RDizzl3_seven
# 0                    Phones and driving  persuade_corpus          False
# ...
